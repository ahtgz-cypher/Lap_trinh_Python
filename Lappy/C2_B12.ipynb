# %%
from math import *

# %%
cost = float(input("Nhap chi phi cua bua an: "))
# Out:
# Nhap chi phi cua bua an:  50000

# %%
thue = cost * 0.05

# %%
hoa_hong = cost * 0.18

# %%
tong_cong = cost * 0.18 * 0.05

# %%
print("Thue la: {:.2f}".format(thue))
# Out:
# Thue la: 2500.00

# %%
print("Hoa hong la: {:.2f}".format(hoa_hong))
# Out:
# Hoa hong la: 9000.00

# %%
print("Chi phi cua bua an la: {:.2f}".format(cost_final))
# Out:
# Chi phi cua bua an la: 450.00
