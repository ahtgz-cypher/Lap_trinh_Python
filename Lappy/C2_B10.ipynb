# %%
from math import *

# %%
dai = float(input("Enter chieu dai: "))
# Out:
# Enter chieu dai:  12

# %%
rong = float(input("Enter chieu rong: "))
# Out:
# Enter chieu rong:  15

# %%
S = dai*rong

# %%
print("Dien tich can phong la
