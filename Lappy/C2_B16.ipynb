# %%
from math import *

# %%
d = float(input("Enter d: "))
# Out:
# Enter d:  20

# %%
vi = 0

# %%
a = 9.8

# %%
vf = sqrt(vi**2 + 2*a*d)

# %%
print("Toc do di chuyen cua mot vat khi no cham dat: ", vf)
# Out:
# Toc do di chuyen cua mot vat khi no cham dat:  19.79898987322333
