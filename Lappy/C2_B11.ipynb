# %%
from math import *

# %%
dai = float(input("Enter chieu dai: "))
# Out:
# Enter chieu dai:  17

# %%
rong = float(input("Enter chieu rong: "))
# Out:
# Enter chieu rong:  15

# %%
S = (dai * rong)/43.560

# %%
print("Dien tich canh dong theo Mau Anh la: ", S)
# Out:
# Dien tich canh dong theo Mau Anh la:  5.853994490358127
