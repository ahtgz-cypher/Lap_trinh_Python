# %%
st1 = input("Enter string")
# Out:
# Enter string Nguyen Hoang

# %%
st2 = input("Enter the word that need to replace: ")
# Out:
# Enter the word that need to replace:  Hoang

# %%
st3 = input("Enter the word after being replace: ")
# Out:
# Enter the word after being replace:  Nam

# %%
st1 = st1.replace(st2, st3)

# %%
print(st1)
# Out:
# Nguyen Nam
