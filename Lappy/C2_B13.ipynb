# %%
from math import *

# %%
n = int(input("Enter so nguyen: "))
# Out:
# Enter so nguyen:  15

# %%
 tong = ((n) * (n+1))//2

# %%
print("Tong cua cac so nguyen to la: ", tong)
# Out:
# Tong cua cac so nguyen to la:  120
