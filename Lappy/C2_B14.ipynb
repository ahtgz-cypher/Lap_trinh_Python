# %%
from math import *

# %%
a = float(input("Enter a: "))
# Out:
# Enter a:  15

# %%
b = float(input("Enter b: "))
# Out:
# Enter b:  12

# %%
tong = a + b

# %%
hieu = a - b

# %%
tich = a * b

# %%
thuong = a // b

# %%
du = a % b

# %%
loga = log(a, 10)

# %%
mu = a ** b

# %%
print("Tong: ", tong)
# Out:
# Tong:  27.0

# %%
print("Hieu: ", hieu)
# Out:
# Hieu:  3.0

# %%
print("Tich: ", tich)
# Out:
# Tich:  180.0

# %%
print("Thuong: ", thuong)
# Out:
# Thuong:  1.0

# %%
print("Thuong lay du: ", du)
# Out:
# Thuong lay du:  3.0

# %%
print("Logarit: ", loga)
# Out:
# Logarit:  1.1760912590556811

# %%
print("Mu: ", mu)
# Out:
# Mu:  129746337890625.0
