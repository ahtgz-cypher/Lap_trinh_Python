# %%
from math import *

# %%
r = float(input("Enter r: "))
# Out:
# Enter r:  12

# %%
h = float(input("Enter h: "))
# Out:
# Enter h:  18

# %%
V = pi * r**2 * h

# %%
print("The tich la: ", V)
# Out:
# The tich la:  8143.008158104743
