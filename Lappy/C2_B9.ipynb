# %%
from math import *

# %%
a = float(input("Enter a: "))
# Out:
# Enter a:  12

# %%
b = float(input("Enter b: "))
# Out:
# Enter b:  12

# %%
c = float(input("Enter c: "))
# Out:
# Enter c:  12

# %%
GocA = float(input("Enter GocA: "))
# Out:
# Enter GocA:  60

# %%
GocB = float(input("Enter GocB: "))
# Out:
# Enter GocB:  60

# %%
GocC = float(input("Enter GocC: "))
# Out:
# Enter GocC:  60

# %%
S1 = 0.5*a*b*sin(radians(GocC))

# %%
S2 = 0.5*b*c*sin(radians(GocA))

# %%
S3 = 0.5*a*c*sin(radians(GocB))

# %%
print("Dien tich S1: ", S1)
print("Dien tich S2: ", S2)
print("Dien tich S3: ", S3)
# Out:
# Dien tich S1:  62.35382907247958
# Dien tich S2:  62.35382907247958
# Dien tich S3:  62.35382907247958

# %%
# Nhan xet: khi ta tính diện tích bằng công thức nào trong 2 bài trên với cùng độ dài
