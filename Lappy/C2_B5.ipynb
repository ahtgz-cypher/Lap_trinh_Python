# %%
st = input("Enter string: ")
# Out:
# Enter string:  Hello world!

# %%
five_before = st[:5]

# %%
five_after = st[len(s1)-5:]

# %%
four_string_in_one_line = 4*(st + " ")

# %%
four_string_in_four_line = 4*(st + "\n")

# %%
print(five_before)
# Out:
# Hello

# %%
print(five_after)
# Out:
# yone!

# %%
print(four_string_in_one_line)
# Out:
# Hello everyone! Hello everyone! Hello everyone! Hello everyone!

# %%
print(four_string_in_four_line)
# Out:
# Hello everyone!
# Hello everyone!
# Hello everyone!
# Hello everyone!
