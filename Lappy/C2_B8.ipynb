# %%
from math import *

# %%
a = float(input("Enter a: "))
# Out:
# Enter a:  12

# %%
S = a**2*(sqrt(3)/4)

# %%
print("Dien tich tam giac deu: ", S)
# Out:
# Dien tich tam giac deu:  62.35382907247958
