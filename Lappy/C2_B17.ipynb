# %%
from math import *

# %%
T_a = float(input("Nhap nhiet do khong khi: "))
# Out:
# Nhap nhiet do khong khi:  4

# %%
V = float(input("Enter toc do gio km/h: "))
# Out:
# Enter toc do gio km/h:  50

# %%
WCL = 13.12 + 0.6215*T_a-11.37*V**0.16 +0.3965*T_a*V**0.16

# %%
print("Chi so gio lanh: ", WCL)
# Out:
# Chi so gio lanh:  -2.689810134846998
